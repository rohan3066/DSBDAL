# %%
import pandas as pd

# %%
df=pd.read_csv('adult_dataset.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
us_subset = df[df['native-country'] == 'United-States']
mexico_subset = df[df['native-country'] == 'Mexico']

# %%
male_subset=df[df['gender']=='Male']
female_subset=df[df['gender']=='Female']

# %%
white_subset = df[df['race'] == 'White']
black_subset = df[df['race'] == 'Black']

# %%
us_subset
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
mexico_subset
# Out:
#        age workclass  fnlwgt  education  educational-num  \
# 46      39   Private  290208    7th-8th                4
# 54      38   Private  219446        9th                5
# 72      30   Private  229636    HS-grad                9
# 217     21   Private  447488    5th-6th                3
# 323     52   Private   55608    1st-4th                2
# ...    ...       ...     ...        ...              ...
# 48613   26   Private  233777    HS-grad                9
# 48615   24   Private  176580    5th-6th                3
# 48706   23   Private  180771    1st-4th                2
# 48713   36   Private  208068  Preschool                1
# 48828   43   Private  260761    HS-grad                9
#
#               marital-status         occupation    relationship  \
# 46        Married-civ-spouse       Craft-repair         Husband
# 54     Married-spouse-absent    Exec-managerial   Not-in-family
# 72        Married-civ-spouse  Machine-op-inspct         Husband
# ...

# %%
male_subset
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 5       34    Private  198693          10th                6
# ...    ...        ...     ...           ...              ...
# 48834   32    Private  116138       Masters               14
# 48835   53    Private  321865       Masters               14
# 48836   22    Private  310152  Some-college               10
# 48838   40    Private  154374       HS-grad                9
# 48840   22    Private  201490       HS-grad                9
#
#            marital-status         occupation   relationship  \
# 0           Never-married  Machine-op-inspct      Own-child
# 1      Married-civ-spouse    Farming-fishing        Husband
# ...

# %%
female_subset
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 4       18             ?  103497  Some-college               10
# 8       24       Private  369667  Some-college               10
# 12      26       Private   82091       HS-grad                9
# 17      43       Private  128354       HS-grad                9
# 18      37       Private   60548       HS-grad                9
# ...    ...           ...     ...           ...              ...
# 48827   37       Private  198216    Assoc-acdm               12
# 48830   43     State-gov  255835  Some-college               10
# 48837   27       Private  257302    Assoc-acdm               12
# 48839   58       Private  151910       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation    relationship   race  gender  \
# 4           Never-married                  ?       Own-child  White  Female
# ...

# %%
white_subset
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 1       38           Private   89814       HS-grad                9
# 2       28         Local-gov  336951    Assoc-acdm               12
# 4       18                 ?  103497  Some-college               10
# 5       34           Private  198693          10th                6
# 7       63  Self-emp-not-inc  104626   Prof-school               15
# ...    ...               ...     ...           ...              ...
# 48837   27           Private  257302    Assoc-acdm               12
# 48838   40           Private  154374       HS-grad                9
# 48839   58           Private  151910       HS-grad                9
# 48840   22           Private  201490       HS-grad                9
# 48841   52      Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# ...

# %%
black_subset
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 0       25   Private  226802          11th                7
# 3       44   Private  160323  Some-college               10
# 6       29         ?  227026       HS-grad                9
# 21      34   Private  238588  Some-college               10
# 27      23   Private  134446       HS-grad                9
# ...    ...       ...     ...           ...              ...
# 48802   33   Private  273243       HS-grad                9
# 48816   22   Private  325033          12th                8
# 48818   30   Private  345898       HS-grad                9
# 48819   38   Private  139180     Bachelors               13
# 48822   41         ?  202822       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# ...

# %%
merged_subset=pd.concat([us_subset,mexico_subset],ignore_index=True)

# %%
merged_subset
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 4       18          ?  103497  Some-college               10
# ...    ...        ...     ...           ...              ...
# 44778   26    Private  233777       HS-grad                9
# 44779   24    Private  176580       5th-6th                3
# 44780   23    Private  180771       1st-4th                2
# 44781   36    Private  208068     Preschool                1
# 44782   43    Private  260761       HS-grad                9
#
#               marital-status         occupation   relationship  \
# 0              Never-married  Machine-op-inspct      Own-child
# 1         Married-civ-spouse    Farming-fishing        Husband
# ...

# %%
sorted_data=df.sort_values(by='capital-gain')

# %%
sorted_data
# Out:
#        age     workclass  fnlwgt    education  educational-num  \
# 20      34       Private  107914    Bachelors               13
# 46070   26       Private  157028      Masters               14
# 48821   45     State-gov  252208      HS-grad                9
# 48820   71             ?  287372    Doctorate               16
# 48818   30       Private  345898      HS-grad                9
# ...    ...           ...     ...          ...              ...
# 48371   66       Private  115498    Bachelors               13
# 5680    34       Private  128016    Bachelors               13
# 45916   37       Private  171150    Bachelors               13
# 46087   38       Private  100375  Prof-school               15
# 83      44  Self-emp-inc  223881      HS-grad                9
#
#            marital-status       occupation   relationship   race  gender  \
# 20     Married-civ-spouse     Tech-support        Husband  White    Male
# ...

# %%
transopose_data=df.transpose();

# %%
transopose_data.head()
# Out:
#                    0        1           2             3             4      \
# age                   25       38          28            44            18
# workclass        Private  Private   Local-gov       Private             ?
# fnlwgt            226802    89814      336951        160323        103497
# education           11th  HS-grad  Assoc-acdm  Some-college  Some-college
# educational-num        7        9          12            10            10
#
#                    5        6                 7             8        9      \
# age                   34       29                63            24       55
# workclass        Private        ?  Self-emp-not-inc       Private  Private
# fnlwgt            198693   227026            104626        369667   104996
# education           10th  HS-grad       Prof-school  Some-college  7th-8th
# educational-num        6        9                15            10        4
#
# ...

# %%
df['ID']=df.index;
melted_df=pd.melt(
    df,
    id_vars=['ID','age','gender','race'],
    value_vars=['capital-gain','capital-loss','hours-per-week'],
    var_name='Metric',
    value_name='Value'
)

# %%
melted_df
# Out:
#            ID  age  gender   race          Metric  Value
# 0           0   25    Male  Black    capital-gain      0
# 1           1   38    Male  White    capital-gain      0
# 2           2   28    Male  White    capital-gain      0
# 3           3   44    Male  Black    capital-gain   7688
# 4           4   18  Female  White    capital-gain      0
# ...       ...  ...     ...    ...             ...    ...
# 146521  48837   27  Female  White  hours-per-week     38
# 146522  48838   40    Male  White  hours-per-week     40
# 146523  48839   58  Female  White  hours-per-week     40
# 146524  48840   22    Male  White  hours-per-week     20
# 146525  48841   52  Female  White  hours-per-week     40
#
# [146526 rows x 6 columns]

# %%
wide_df=melted_df.pivot(
    index=['age','gender','race','ID'],
    columns='Metric',
    values='Value'
).reset_index();

# %%
wide_df
# Out:
# Metric  age  gender                race     ID  capital-gain  capital-loss  \
# 0        17  Female  Amer-Indian-Eskimo   7709             0             0
# 1        17  Female  Amer-Indian-Eskimo  15537             0             0
# 2        17  Female  Amer-Indian-Eskimo  19886          1055             0
# 3        17  Female  Amer-Indian-Eskimo  31001             0             0
# 4        17  Female  Asian-Pac-Islander  17759             0             0
# ...     ...     ...                 ...    ...           ...           ...
# 48837    90    Male               White  40324          2964             0
# 48838    90    Male               White  44744             0             0
# 48839    90    Male               White  47311             0             0
# 48840    90    Male               White  47977             0             0
# 48841    90    Male               White  48648          2653             0
#
# Metric  hours-per-week
# 0                   30
# ...
